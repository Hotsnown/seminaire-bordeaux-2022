# %%
# !git clone https://github.com/Hotsnown/seminaire-bordeaux-2022.git seminaire &> /dev/null
# %pip install nbautoeval &> /dev/null
from seminaire.evaluation.jour1.strings.concat import exo_guillemets_dans_string, exo_apostrophe_dans_string, exo_concat, exo_formatte
# Out:
# La syntaxe de la commande n'est pas correcte.
# Note: you may need to restart the kernel to use updated packages.
# La syntaxe de la commande n'est pas correcte.

# %% [markdown]
# ## Qu'est ce qu'un string ?
#
# Un string est un texte.
# Pour déclarer un string, vous pouvez utiliser soit ma_variable = 'valeur initiale' (apostrophes), soit ma_variable = "valeur initiale" (guillemets doubles).
#
# Dans les exemples suivants, créz le string indiqué.

# %% [markdown]
# ### Apostrophes
#
# Remplacez #TODO par 'Il y a des "doubles guillemets" dans ce string.'

# %%
def guillemets_dans_string():
  return #TODO

exo_guillemets_dans_string.correction(guillemets_dans_string)

# %% [markdown]
# ### Guillemets
#
# Remplacez #TODO par "Une apostrophe peut s'inclure dans un string."

# %%
def apostrophe_dans_string():
    return #TODO

exo_apostrophe_dans_string.correction(apostrophe_dans_string)

# %% [markdown]
# ### CONCATENATION

# %% [markdown]
# Nous pouvons combiner plusieurs sous-string en utilisant le signe plus (+). Par exemple, "Droit" + "Civil" est équivalent au string "DroitCivil".

# %% [markdown]
# Dans l'exercice suivant, concaténez ma_variable1 et ma_variable2.

# %%
exo_concat.example()

# %%
def concat():  
  
  ma_variable1 = "Hello"
  ma_variable2 = "World"

  mon_nouveau_string = #TODO

  ## Ne rien changer après cette ligne
  return mon_nouveau_string

exo_concat.correction(concat)
# Out:
#   Input In [3]
#     ma_variable1 =
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### FORMATTAGE

# %% [markdown]
# Les string peuvent être formatées à l'aide de l'opérateur %. La syntaxe de l'opérateur % est la suivante <br />
#
# "string à formater" %(variables à insérer dans le string, séparées par des virgules) <br />
#
# Cette syntaxe comporte trois parties. Tout d'abord, nous écrivons le string entre guillemets. Ensuite, nous écrivons le symbole %. Enfin, nous avons une paire de parenthèses ( ) à l'intérieur desquelles nous écrivons les variables à insérer dans le string.
#
# Dans l'exercice suivant, formattez le string "Bonjour nom!" où nom est une variable qui vous est donné.

# %%
exo_formatte.example()

# %%
def formatte(nom):
    msg = "Bonjour #TODO !"
    return msg

exo_formatte.correction(formatte)

# %% [markdown]
# 1. Jour 1
#     * Variables
#         * [exercice1](https://colab.research.google.com/github/Hotsnown/seminaire-bordeaux-2022/blob/master/exercices/jour1/1.%20variables/1.1%20helloworld.ipynb)
#         * [exercice2](https://colab.research.google.com/github/Hotsnown/seminaire-bordeaux-2022/blob/master/exercices/jour1/1.%20variables/1.2%20%C3%A9viter%20les%20errreurs%20de%20nommage.ipynb)
#         * [mini-projet](https://colab.research.google.com/github/Hotsnown/seminaire-bordeaux-2022/blob/master/exercices/jour1/1.%20variables/1.3%20mini-project.ipynb#scrollTo=RPB2xCMdA6lV)
#     * Strings
#         * [exercice1](https://colab.research.google.com/github/Hotsnown/seminaire-bordeaux-2022/blob/master/exercices/jour1/2.%20strings/2.1%20concat.ipynb)
#         * [exercice2](https://colab.research.google.com/github/Hotsnown/seminaire-bordeaux-2022/blob/master/exercices/jour1/2.%20strings/2.2%20string_methods.ipynb)
#         * [mini-projet](https://colab.research.google.com/github/Hotsnown/seminaire-bordeaux-2022/blob/master/exercices/jour1/2.%20strings/2.3%20mini-project.ipynb)
#     * Opérations
#         * [exercice1](https://colab.research.google.com/github/Hotsnown/seminaire-bordeaux-2022/blob/master/exercices/jour1/3.%20operations/3.1%20math.ipynb)
#         * [exercice2](https://colab.research.google.com/github/Hotsnown/seminaire-bordeaux-2022/blob/master/exercices/jour1/3.%20operations/3.2%20bool%C3%A9en.ipynb)
#         * [mini-projet](https://colab.research.google.com/github/Hotsnown/seminaire-bordeaux-2022/blob/master/exercices/jour1/3.%20operations/3.3%20mini-project.ipynb)
