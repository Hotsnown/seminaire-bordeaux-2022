# %%
Opérateurs
Le langage Python supporte plusieurs types d'opérateurs. Dans cette section, nous allons nous concentrer sur quelques-uns d'entre eux.

Opérateurs d'assignation
Les opérateurs d'assignation sont utilisés pour attribuer des valeurs aux variables. Prenons l'exemple de =. Le signe égal en mathématiques indique que deux valeurs sont égales, mais en Python, il signifie que nous stockons une valeur dans une certaine variable et nous l'appelons affectation ou attribution de valeur à une variable. Le tableau ci-dessous montre les différents types d'opérateurs d'affectation en Python, tirés de w3school.

Opérateurs d'affectation

Opérateurs arithmétiques :
Addition(+) : a + b
Soustraction(-) : a - b
Multiplication(*) : a * b
Division(/) : a / b
Modulus(%) : a % b
Division plancher(//) : a // b
Exponentiation(**) : a ** b
Opérateurs arithmétiques

Exemple:Entiers

# Opérations arithmétiques en Python
# Entiers

print('Addition : ', 1 + 2) # 3
print('Soustraction : ', 2 - 1) # 1
print('Multiplication : ', 2 * 3) # 6
print('Division : ', 4 / 2) # 2.0 La division en Python donne un nombre flottant
print('Division : ', 6 / 2) # 3.0         
print('Division : ', 7 / 2) # 3.5
print('Division sans le reste : ', 7 // 2) # 3, donne sans le nombre flottant ou sans le reste
print ('Division sans le reste : ',7 // 3) # 2
print('Modulus : ', 3 % 2) # 1, Donne le reste
print('Exponentiation : ', 2 ** 3) # 9 cela signifie 2 * 2 * 2
Exemple : nombres flottants

# Nombres flottants
print('Nombre à virgule flottante, PI', 3.14)
print('Nombre en virgule flottante, gravité', 9.81)
Exemple:Nombres complexes

# Nombres complexes
print('Nombre complexe : ', 1 + 1j)
print('Multiplication de nombres complexes : ',(1 + 1j) * (1 - 1j))
Déclarons une variable et attribuons un type de données numérique. Je vais utiliser une variable à caractère unique, mais n'oubliez pas de ne pas prendre l'habitude de déclarer ce type de variables. Les noms de variables doivent toujours être mnémotechniques.

Exemple :

# Déclarer d'abord la variable du début

a = 3 # a est un nom de variable et 3 est un type de données entier
b = 2 # b est un nom de variable et 3 est un type de données entier

# Opérations arithmétiques et affectation du résultat à une variable
total = a + b
diff = a - b
produit = a * b
division = a / b
reste = a % b
division_fond = a // b
exponentiel = a ** b

# J'aurais dû utiliser sum au lieu de total mais sum est une fonction intégrée - essayez d'éviter de surcharger les fonctions intégrées
print(total) # Si vous ne marquez pas votre impression avec une chaîne de caractères, vous ne saurez jamais d'où vient le résultat.
print('a + b = ', total)
print('a - b = ', diff)
print('a * b = ', product)
print('a / b = ', division)
print('a % b = ', remainder)
print('a // b = ', division_fond)
print('a ** b = ', exponentiation)
Exemple :

print('== Addition, Soustraction, Multiplication, Division, Modulus ==')

# Déclarer des valeurs et les organiser ensemble
num_one = 3
num_two = 4

# Opérations arithmétiques
total = num_one + num_two
diff = num_two - num_one
produit = num_one * num_two
div = num_two / num_one
reste = num_two % num_one

# Impression des valeurs avec étiquette
print('total : ', total)
print('différence : ', diff)
print('produit : ', produit)
print('division : ', div)
print('remainder : ', remainder)
Commençons à relier les points et à utiliser ce que nous savons déjà pour calculer (surface, volume, densité, poids, périmètre, distance, force).

Exemple :

# Calcul de l'aire d'un cercle
radius = 10 # rayon d'un cercle
aire_du_cercle = 3,14 * rayon ** 2 # deux * signe signifie exposant ou puissance
print('Surface d'un cercle:', surface_du_cercle)

# Calcul de l'aire d'un rectangle
longueur = 10
largeur = 20
surface_du_rectangle = longueur * largeur
print('Surface d'un rectangle:', surface_du_rectangle)

# Calculer le poids d'un objet
masse = 75
gravité = 9.81
poids = masse * gravité
print(weight, 'N') # Ajout d'une unité au poids

# Calculer la densité d'un liquide
masse = 75 # en kg
volume = 0,075 # en mètre cube
densité = masse / volume # 1000 Kg/m^3

# %% [markdown]
# 1. Déclarez votre âge comme variable entière
# 2. Déclarez votre taille en tant que variable flottante
# 3. Déclarer une variable qui stocke un nombre complexe
# 4. Ecrivez un script qui demande à l'utilisateur d'entrer la base et la hauteur du triangle et de calculer l'aire de ce triangle (aire = 0,5 x b x h).
#     Entrez la base : 20
#     Entrez la hauteur : 10
#     L'aire du triangle est de 100
# 5. Écrivez un script qui demande à l'utilisateur d'entrer le côté a, le côté b et le côté c du triangle. Calculez le périmètre du triangle (périmètre = a + b + c).
# Entrez le côté a : 5
# Entrez le côté b : 4
# Entrez le côté c : 3
# Le périmètre du triangle est de 12
# 6. Obtenez la longueur et la largeur d'un rectangle en utilisant l'invite. Calculez son aire (aire = longueur x largeur) et son périmètre (périmètre = 2 x (longueur + largeur)).
# 7. Déterminez le rayon d'un cercle à l'aide de l'invite. Calculez son aire (aire = pi x r x r) et sa circonférence (c = 2 x pi x r) où pi = 3,14.
# 8. Calculez la pente, l'ordonnée à l'origine en x et l'ordonnée à l'origine en y de y = 2x -2.
# La pente est (m = y2-y1/x2-x1). Trouver la pente et la distance euclidienne entre le point (2, 2) et le point (6, 10).
# 9. Compare les pentes des tâches 8 et 9.
# 10. Calculez la valeur de y (y = x^2 + 6x + 9). Essayez d'utiliser différentes valeurs de x et déterminez à quelle valeur de x y sera égal à 0.
#
# 11. Trouvez la longueur de " python " et de " dragon " et faites une déclaration de comparaison erronée.
# 12. Utilisez l'opérateur et pour vérifier si " on " se trouve à la fois dans " python " et " dragon ".
# 13. J'espère que ce cours n'est pas rempli de jargon. Utilisez l'opérateur in pour vérifier si le jargon est présent dans la phrase.
# 14. Il n'y a pas de "on" dans "dragon" et "python".
# 15. Trouvez la longueur du texte en python, convertissez la valeur en flottant et convertissez-la en chaîne de caractères.
# 16. Les nombres pairs sont divisibles par 2 et le reste est égal à zéro. Comment vérifier si un nombre est pair ou non en utilisant python ?
# 17. Vérifiez si la division plancher de 7 par 3 est égale à la valeur convertie en int de 2,7.
# 18. Vérifier si le type de '10' est égal au type de 10. 19.
# 19. Vérifier si int('9.8') est égal à 10.
# 20. Ecrivez un script qui demande à l'utilisateur d'entrer les heures et le taux horaire. Calculer le salaire de la personne ?
# Entrez les heures : 40
# Taux horaire : 28
# Votre salaire hebdomadaire est de 1120
# 21. Ecrivez un script qui demande à l'utilisateur d'entrer le nombre d'années. Calculez le nombre de secondes qu'une personne peut vivre. Supposons qu'une personne puisse vivre cent ans
# Entrez le nombre d'années que vous avez vécues : 100
# Vous avez vécu 3153600000 secondes.
# 22. Ecrivez un script Python qui affiche le tableau suivant
#
# 1 1 1 1 1
# 2 1 2 4 8
# 3 1 3 9 27
# 4 1 4 16 64
# 5 1 5 25 125
